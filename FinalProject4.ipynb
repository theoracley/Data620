# %% [markdown]
# # WEB ANALYTICS - FINAL PROJECT
# ### Group: Abdelmalek Hajjam, Monu Chacko

# %% [markdown]
# For the final project we will use the knowledge gained in the class to analyze a dataset of comments for a given discussion. We will Take a discussion thread from reddit and analyze its comments. Reddit is a social news aggregation site, rating contents, and discussions. Registered members submit content to the site such as links, text posts, and images, which are then voted up or down by other members. This network can be analyzed to determine its sentiment and network itself. Kaggle provides us many datasets that are collected from many places. It also includes comments data from reddit. We can use this dataset to do our analysis. Reddit comments dataset https://www.kaggle.com/reddit/reddit-comments-may-2015 contains about 1.7 billion records. To perform analysis, kaggle provides us a smaller subset of data. We took that subset and reduced further to get a new subset of decent csv files that can be read and analyzed. All comments and users used in these 3 CSV files we are going to use, are coming from a single subreddit or subject, in this case it was "What is the strongest opinion you hold?".
#
# In this project, we will use 2 parts. One part to study the network analysis where the nodes are the users and the edges between any 2 nodes are all the comments and recomments between any 2 users, and the other part to do sentimental analysis on the comments. So let's go!!!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import operator
import numpy as np
import scipy.stats
import nltk
import warnings
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#nltk.download('vader_lexicon')
warnings.filterwarnings('ignore')

# %%
# Load the comments and users data
reddit = pd.read_csv('comments_grp_data.csv',sep=',')
reddit_comment = pd.read_csv('comments_data.csv',sep=';')
users = pd.read_csv('users_data.csv',sep=';')

# %%
# View the data
reddit.loc[0:15]
# Out:
#                   author             responder  weight
# 0   ---DevilsAdvocate---              dannybtw       1
# 1   ---DevilsAdvocate---         ThisFreaknGuy       2
# 2            -Covariance             DomeSlave       1
# 3        -Mountain-King-  ASK_ABOUT_STEELBEAMS       3
# 4        -Mountain-King-        AvoidNoiderman       2
# 5        -Mountain-King-         Bigfrostynugs       1
# 6        -Mountain-King-             Dsiroon37       1
# 7        -Mountain-King-              giantzoo       1
# 8        -Mountain-King-               iramo94       3
# 9        -Mountain-King-           omegashadow       1
# 10       -Mountain-King-           redditminus       1
# 11       -Mountain-King-             Tom_Stall       2
# 12             -shitgun-           Chucklebuck       1
# 13      -ThatGuyOnReddit                thedoh       1
# 14      -ThatGuyOnReddit                Veeron       1
# 15  -TheCabbageMerchant-            Dapianoman       1

# %%
print("Shape of reddit dataset:", reddit.shape)
print("Shape of comments dataset:", reddit_comment.shape)
print("Shape of users dataset:", users.shape)
# Out:
# Shape of reddit dataset: (18701, 3)
# Shape of comments dataset: (24134, 13)
# Shape of users dataset: (9928, 3)

# %%
# Initialize graph
G = nx.Graph()

# Add nodes
nodes = set(reddit.loc[:, "author"])
nodes.union(set(reddit.loc[:, "responder"]))
nodes = list(nodes)
nodes
G.add_nodes_from(nodes)

# Add edges with weights
G.add_weighted_edges_from([tuple(x) for x in reddit.values])

# %% [markdown]
# ### View the network

# %%
# %matplotlib inline
fig = plt.figure(figsize=(18, 18))
nx.draw(G)
plt.show()

# %% [markdown]
# ### Diagram of the entire network using Gephi

# %% [markdown]
# We also use Gephi for our analysis. Gephi is an open-source network analysis and visualization software package. It provides us powerful interactive tools to work with networks. Following is the view of the entire network.

# %% [markdown]
# ![Network](https://raw.githubusercontent.com/monuchacko/WebAnalytics/master/networkdia2.png)

# %% [markdown]
# ### We used Gephis ForceAtlas 2 preset to generate network diagram
#
# Force Atlas 2 attempts to resolve the shortcomings of the Force Atlas algorithm by making a balance between the quality of the final layout and the speed of the computation algorithm. Its performance for large networks is much better when compared to the Force Atlas layout algorithm. Please see the network generated using Force Atlas 2

# %% [markdown]
# ![Network](https://raw.githubusercontent.com/monuchacko/WebAnalytics/master/networkdia1.png)

# %% [markdown]
# ### Now that we have our graph, let's analyze it and reveal some of its properties

# %%
# Total number of nodes
nx.number_of_nodes(G)
# Out:
# 10233

# %%
# Number of edges
G.number_of_edges()
# Out:
# 15756

# %%
# Number of connected components
nx.number_connected_components(G)
# Out:
# 129

# %%
# Ten largest subgraphs
[len(c) for c in sorted(nx.connected_components(G), key=len, reverse=True)[0:10]]
# Out:
# [9928, 9, 6, 5, 5, 5, 5, 5, 4, 4]

# %%
# Select the largest connected subgraph
G = max(nx.connected_component_subgraphs(G), key=len)
G.number_of_nodes()
# Out:
# 9928

# %%
nx.diameter(G)
# Out:
# 16

# %%
nx.average_shortest_path_length(G, weight='weight')
# Out:
# 5.211905025136356

# %%
# Calculate betweenness centrality
centr_bw = nx.betweenness_centrality(G, weight='weight')

# Calculate degree centrality
centr_deg = nx.degree_centrality(G)

# Combine betweenness and degree centralities into a single data frame
df1 = pd.DataFrame(list(centr_bw.items()), columns=['User', 'Betweenness'])
df2 = pd.DataFrame(list(centr_deg.items()), columns=['User', 'Degree'])
users = df1.join(df2.set_index('User'), on='User')
users.sort_values(['Betweenness', 'Degree'], ascending = False, inplace=True)

users[0:25]
# Out:
#                      User  Betweenness    Degree
# 1743                 CDC_     0.087609  0.035560
# 3014             corby315     0.074198  0.023471
# 2620             fundygud     0.051563  0.020248
# 1397             Lemonaxe     0.049766  0.021557
# 128             bazzil350     0.049643  0.019845
# 273             hawkish25     0.049423  0.017125
# 4119      Supersoakthatho     0.048042  0.017729
# 2509           FenrisCain     0.046511  0.018535
# 1923             ohitsali     0.045828  0.018535
# 781            mstrdpncks     0.045789  0.017528
# 3523             tehweave     0.044902  0.016218
# 2867        franklymydeer     0.040771  0.014405
# 90           palettendieb     0.039118  0.017830
# 2987           GameSkatez     0.038556  0.016420
# 1105        killminusnine     0.033650  0.012995
# 3951          redditminus     0.031578  0.010577
# 40            MrConfucius     0.031088  0.015211
# 4105  BillMaher4President     0.030286  0.014304
# 3390           smileedude     0.029680  0.012995
# 2580               NicoUK     0.027325  0.011585
# 782                Bt1222     0.026446  0.011786
# 1122            Baastrami     0.026258  0.010779
# 2053         CatNamedJava     0.024806  0.005138
# 1946    quentin-coldwater     0.023442  0.010577
# 2869       FearlessParrot     0.022165  0.010980

# %% [markdown]
# ### Let's check on a user and his interactions in the graph. In this case we check on user "CatNamedJava"

# %%
# %matplotlib inline
fig = plt.figure(figsize=(18, 18))

main = 'CatNamedJava'

# Select neighbors and neighbors of neighbors
subG = G.neighbors(main)

n_list = subG
for n in subG:
    n_list = list(n_list) + [G.neighbors(n)]
n_list = list(set(n_list))
n_list.append(main)

# Isolate the subnetwork
subG = G.subgraph(n_list)

# Get color map
colormap =[]
for n in subG.nodes():
    if n==main:
        colormap.append('yellow')
    else:
        colormap.append('red')
     
# Separate edges by weight - 1 and more than 1
elarge=[(u,v) for (u,v,d) in subG.edges(data=True) if d['weight']>1]
esmall=[(u,v) for (u,v,d) in subG.edges(data=True) if d['weight']==1]

# Layout
pos=nx.spring_layout(subG)

# Draw nodes
nx.draw_networkx_nodes(subG,pos,node_color=colormap,node_size=30)

# Draw edges
nx.draw_networkx_edges(subG, pos, edgelist=elarge, width=2, edge_color='r')
nx.draw_networkx_edges(subG, pos, edgelist=esmall, width=1, edge_color='grey', style='dashed')

plt.axis('off')
plt.show()
plt.gcf().clear()

# %% [markdown]
# ### Diagram applying filters for range (betweeness centrality) and degree range in Gephi

# %% [markdown]
# ![Network](https://raw.githubusercontent.com/monuchacko/WebAnalytics/master/betweennesscentra.png)

# %% [markdown]
# ### Diagram showling Closeness Centrality in Gephi

# %% [markdown]
# ![Network](https://raw.githubusercontent.com/monuchacko/WebAnalytics/master/closenesscentra.png)

# %%
# Save network
#nx.write_graphml(G, "rd.graphml")

# %% [markdown]
# ## SENTIMENT ANALYSIS

# %% [markdown]
# VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media. VADER uses a combination of A sentiment lexicon is a list of lexical features (e.g., words) which are generally labeled according to their semantic orientation as either positive or negative. VADER not only tells about the Positivity and Negativity score but also tells us about how positive or negative a sentiment is.

# %%
sentiment = pd.read_excel('sentiment_data.xlsx')

# %%
def sentiment_scores(sentence): 
  
    # Create a SentimentIntensityAnalyzer object. 
    sid_obj = SentimentIntensityAnalyzer() 
  
    # polarity_scores method of SentimentIntensityAnalyzer 
    # oject gives a sentiment dictionary. 
    # which contains pos, neg, neu, and compound scores. 
    sentiment_dict = sid_obj.polarity_scores(sentence) 
      
    print("Overall sentiment dictionary is : ", sentiment_dict) 
    print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative") 
    print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral") 
    print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive") 
  
    print("Sentence Overall Rated As", end = " ") 
  
    # decide sentiment as positive, negative and neutral 
    if sentiment_dict['compound'] >= 0.05 : 
        print("Positive") 
  
    elif sentiment_dict['compound'] <= - 0.05 : 
        print("Negative") 
  
    else : 
        print("Neutral")

# %%
print("Test for sentiment score") 
sentence = "Geeks For Geeks is the best portal for the computer science engineering students." 

# function calling 
sentiment_scores(sentence) 

print("\n2nd Statement :") 
sentence = "study is going on as usual"
sentiment_scores(sentence) 

print("\n3rd Statement :") 
sentence = "I am vey sad today."
sentiment_scores(sentence)
# Out:
# Test for sentiment score
# Overall sentiment dictionary is :  {'neg': 0.165, 'neu': 0.588, 'pos': 0.247, 'compound': 0.5267}
# sentence was rated as  16.5 % Negative
# sentence was rated as  58.8 % Neutral
# sentence was rated as  24.7 % Positive
# Sentence Overall Rated As Positive
#
# 2nd Statement :
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
#
# 3rd Statement :
# Overall sentiment dictionary is :  {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}
# sentence was rated as  50.8 % Negative
# sentence was rated as  49.2 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative

# %% [markdown]
# #### All sentiments in the comments file were calculated through the above function and compiled into the excel above to save time.

# %%
sentiment[0:10]
# Out:
#    Unnamed: 0       id       author        responder  \
# 0           0  1320251  redditminus         Wheeeler
# 1           1  1320252  redditminus         corby315
# 2           2  1320253  redditminus         Theemuts
# 3           3  1320254  redditminus           phuicy
# 4           4  1320255  redditminus   qwerty12qwerty
# 5           5  1320256  redditminus  thegreatestajax
# 6           6  1320257  redditminus        Tom_Stall
# 7           7  1320258  redditminus     gamecock5446
# 8           8  1320259  redditminus            Thil0
# 9           9  1320260  redditminus          Maharog
#
#                                              comment sentiment  compound  \
# 0                                   With face herpes       neu    0.0000
# 1  Unfortunately it's the kids that end up gettin...       neu   -0.6597
# 2  Nah man, freedom of choice and fuck all conseq...       neu    0.3549
# 3  They only real solution is education, because ...       neu   -0.2263
# 4  Heard a good quote a few years back in Governm...       neu    0.8555
# 5  Really? The last personal moral stance that yo...       neu   -0.6072
# 6                    Such a brave opinion on reddit.       neu    0.5267
# 7  I think Jenny McCarthy is personally responsib...       neu   -0.2500
# 8  what if scientists find out in a couple of yea...       neu   -0.3971
# 9  Their children dying of preventable diseases s...       neu   -0.0258
#
#      neg    neu    pos
# 0  0.000  1.000  0.000
# 1  0.403  0.597  0.000
# 2  0.213  0.557  0.230
# 3  0.173  0.703  0.124
# 4  0.070  0.704  0.226
# 5  0.220  0.780  0.000
# 6  0.000  0.541  0.459
# 7  0.226  0.616  0.158
# 8  0.139  0.751  0.110
# 9  0.314  0.378  0.308

# %%
# Top 10 negative comments
sentiment.sort_values(['compound'], ascending = True)[0:10]
# Out:
#        Unnamed: 0       id                author       responder  \
# 21099       21099  1362638    illTwinkleYourStar  AppleCoreThing
# 14532       14532  1345163          kwhitegocubs   toThe9thPower
# 4840         4840  1328721            SnakeHelah     maypolecrup
# 8316         8316  1334623    StraightTalkAdvice        digiacom
# 23507       23507  1395865  PM_Tits_4_LifeMottos        Pixiepup
# 21301       21301  1363913         Altered_Amiba          besjbo
# 20776       20776  1361273         Altered_Amiba          besjbo
# 3144         3144  1325119   BillMaher4President       machenise
# 21141       21141  1362843                besjbo   Altered_Amiba
# 20514       20514  1360148                besjbo   Altered_Amiba
#
#                                                  comment sentiment  compound  \
# 21099  I agree with most of this comment, about the p...       neu   -0.9990
# 14532  &gt; Revenge does not unrape the raped, resurr...       neu   -0.9990
# 4840   &gt; I don't understand the now rising and pop...       neu   -0.9989
# 8316   First, [H.L. Mencken](http://grammar.about.com...       neu   -0.9988
# 23507  I'm trying to feel you here, but things like "...       neu   -0.9987
# 21301  &gt;But you can't prove those are the same peo...       neu   -0.9986
# 20776  &gt;The group itself isn't that way and the wh...       neu   -0.9983
# 3144   There are actually some pretty good arguments ...       neu   -0.9983
# 21141  &gt;I wasn't trying to say that everyone who s...       neu   -0.9983
# 20514  &gt;Will me finding one example of a person em...       neu   -0.9983
#
#          neg    neu    pos
# 21099  0.312  0.591  0.097
# 14532  0.346  0.594  0.060
# 4840   0.259  0.639  0.102
# 8316   0.350  0.571  0.079
# 23507  0.374  0.554  0.072
# 21301  0.170  0.732  0.098
# 20776  0.175  0.754  0.071
# 3144   0.387  0.548  0.065
# 21141  0.181  0.753  0.067
# 20514  0.198  0.728  0.074

# %%
# Most negative comment
comm = sentiment.sort_values(['compound'], ascending = True)[0:1]['comment']
print(str(comm.values.flatten()))
# Out:
# ["I agree with most of this comment, about the problem of feminism being a white middle class movement definitely, and modern feminists need to work to combat that.\r\r\n\r\r\nYou're right that a study on false rape accusations is hard to conduct. But I find your comment about the many men whose lives have been ruined by false rape accusations a little strange, when the number of women and men whose lives have been ruined by actual rape is a much more statistically significant problem. \r\r\n\r\r\nI'm not dismissing false rape accusations, but they are notoriously over-represented in the media and all studies (admittedly never going to be perfect studies) have shown them to be extremely fringe in the face of actual rape cases. The sequence of events following a rape accusation are so unpleasant to make false accusations less appealing. \r\r\n\r\r\nFrom [here] (http://www.shakesville.com/2005/12/dont-just-blame-victim-prosecute-her.html) (and admittedly empassioned article)\r\r\n\r\r\n&gt;Now here are some things that are true. Rape is underreported. Reporting a rape is difficult, and can be embarrassing, shameful, hurtful, frustrating, and too often unfulfilling. Quite bluntly, there is very little incentive to report a rape. Itâ€™s a terrible experience, and the likelihood of seeing justice served is a long shot. Even if it is, it usually comes at great personal cost, with oneâ€™s sexual history put on public display amidst the dismay of reliving the attackâ€”and an extended trial can necessitate living in a state of suspended animation, where moving on from that moment is all but impossible. The only real incentive one has is knowing the sacrifice might prevent the same thing from happening to someone else. Not a small thing, but a big personal investment.\r\r\n\r\r\nLike I said, not dismissing the existence of them and the damage they do, but false rape accusations are part of a big problem we have for dealing with rape, and should be part of a bigger discussion on rape culture and attitudes to rape. \r\r\n\r\r\nAnd really and truly feminism is concerned with men's issues. Things like the child support issue you mentioned earlier, and male domestic abuse/rape cases, and the damages of the pressures of masculinity, and pressure not to show emotion or weakness leading to higher rates of male suicide. Feminism wants to combat all these and more, and actively makes efforts to do so. "]

# %%
# Top 10 positive comments
sentiment.sort_values(['compound'], ascending = False)[0:10]
# Out:
#        Unnamed: 0       id             author             responder  \
# 22830       22830  1379322         bulldoozer        CeasarTheFirst
# 21864       21864  1368247        kingphysics          0therworldly
# 623           623  1321385        MeowMixSong                LadyKa
# 21633       21633  1366494              GMDev               mrgud69
# 18723       18723  1353881      franklymydeer          lsdmthcosmos
# 16693       16693  1349343          Joshoowuh       I_love_propofol
# 20773       20773  1361267           Saytahri  ___OccamsChainsaw___
# 24073       24073  1659093  PsychoPhilosopher          0therworldly
# 20791       20791  1361344            steavoh        lessmiserables
# 8506         8506  1334955        Catatonic27           happybadger
#
#                                                  comment sentiment  compound  \
# 22830  I'm not screaming rhetoric. You implied that m...       neu    0.9990
# 21864  &gt; I'm only going to start my undergrad Phys...       neu    0.9977
# 623    Hard-core, willfully blind, forcing-their-view...       neu    0.9975
# 21633  I absolutely understand where you're coming fr...       neu    0.9975
# 18723  Absolutely, you hit it spot on about the gradi...       neu    0.9973
# 16693  I'm a doctor in the UK. I believe that healthc...       neu    0.9969
# 20773  &gt; Yes I would have, my 2nd example was an e...       neu    0.9968
# 24073  Nice list. Would've been more constructive to ...       neu    0.9964
# 20791  It's one of the issues I do have with conserva...       neu    0.9961
# 8506   We're in a transitional era when it comes to h...       neu    0.9959
#
#          neg    neu    pos
# 22830  0.071  0.729  0.201
# 21864  0.057  0.787  0.156
# 623    0.020  0.759  0.220
# 21633  0.062  0.689  0.249
# 18723  0.052  0.774  0.174
# 16693  0.056  0.778  0.166
# 20773  0.070  0.665  0.265
# 24073  0.087  0.730  0.184
# 20791  0.029  0.785  0.187
# 8506   0.034  0.821  0.145

# %%
# Most positive comment
comm = sentiment.sort_values(['compound'], ascending = False)[0:1]['comment']
print(str(comm.values.flatten()))
# Out:
# ['I\'m not screaming rhetoric. You implied that my intentions we\'re naive and unfounded. I don\'t have all of the answers, no one does. Even if I attempted to answer all of them, there\'s a sound argument against them. You\'re right it\'s not black and white, however, neither is the solution to this. \r\r\n \r\r\nCapitalism is not a long-term sustainable solution, much in the same way communism is not a good conductor of progress/innovation. The nature of both systems lead to failure. \r\r\n \r\r\nCapitalism in the US and abroad has lasted as long as it has because there is a mix of socialism in there; obviously, moreso in the EU than in the US, but it provides a level of sustainability to society. The spoils (money) generated by a capitalist society are partially spread to everyone. In a way one could argue that everyone played a part in everyone\'s success, because things happened the way they did. \r\r\n \r\r\nCapitalism fails in that it\'s not the real system, it\'s just somewhat of a vehicle to a plutocracy; just as communism was a vehicle to an oligarchy. Capitalism is great for 1-2 generations of people, but the spoils of capitalism, being much much more than any one person could potentially spend in their lifetime, get passed down the line. \r\r\n \r\r\nThe sums of money generated by people are not what makes capitalism the better system, it\'s the transformation of people from point A to point B, with money as the incentive. While the person\'s goal is money, the desired outcome, and better reward to the society, is a person going out and making things better by giving people what they want (the Invisible Hand). \r\r\n \r\r\nThe children of that person may learn first-hand what it takes, their children will get the second-hand knowledge, and so on, but no generation after the first one, will really have to struggle, or work hard for the personal incentive of money. The system we have allows for perpetual income without effort. You can say investments feed society with capital, allow for other businesses to flourish, other ideas to be made; which is great and wonderful, but that\'s not how it shakes out. 2008 is a great reminder of that, but for less obvious reasons. \r\r\n \r\r\nThe people who\'s knowhow and skill created a vast amount of wealth, no longer control that wealth. It\'s like some random dude getting Superman\'s powers, without going through what Superman went through. Even then, the people are never fully in charge of that money, their personal wealth manager, investment banker, hedge fund, accountant, they control most of where that money goes, and it\'s for the most part, in businesses that are doing great already. \r\r\n\r\r\n Not only that, but businesses have become more powerful than any one person, or a government can control. The too big to fail policy. The government has oversight. THat\'s why they control our nukes, water, military, food inspections, customs, etc. because those things are too important to be left unsupervised. When a business controls certain segments of society, accountability is out the window. What is there to stop someone from exploiting the situation? Look at the multi-billion dollar fines on banks. They act with utter impunity. \r\r\n \r\r\nTL;DR: Capitalism is great for creating innovation, but also leads to a super plutocracy where a few rich individuals control practically every segment of society, that are somehow justified because they\'re "just *that* good." It encourages division, classism, greed and materialism. \r\r\n \r\r\nSocialism/communism is great for creating a sustainable and equal society, but fails to generate the economic progress and societal motivation needed to generate the means for a society to thrive. \r\r\n \r\r\nCapitalism is too wild and devicsive. Socialism is too tame and homogenous-friendly. Europe can work with socialism because many of their societies are developed and very homogenous, plus they have the cultural identity to identify with. ...

# %%
# Top 10 negative comments
sentiment.sort_values(['neg'], ascending = False)[0:10]
# Out:
#        Unnamed: 0       id                author             responder  \
# 1651         1651  1322940  PM_Tits_4_LifeMottos                mivipa
# 10862       10862  1338623           MrConfucius         BuckYouFungie
# 2210         2210  1323695            smileedude  aeternitatisdaedalus
# 22654       22654  1376050           soloesliber               megaRXB
# 7399         7399  1333126               TheMile      thegreatestprime
# 573           573  1321301            spookyb0ss              kevo7777
# 3404         3404  1326095         killminusnine            Rcmike1234
# 20737       20737  1361118       barbiewannabe23          SeaOfAnarchy
# 16404       16404  1348732           Odd_craving            Robtonight
# 20528       20528  1360203             [deleted]  PMME_YOUR_TITS_WOMAN
#
#             comment sentiment  compound  neg  neu  pos
# 1651   I disagree.        neg   -0.3818  1.0  0.0  0.0
# 10862          No.        neg   -0.2960  1.0  0.0  0.0
# 2210          WRONG       neg   -0.4767  1.0  0.0  0.0
# 22654           No.       neg   -0.2960  1.0  0.0  0.0
# 7399      Disagree.       neg   -0.3818  1.0  0.0  0.0
# 573     bullshit.         neg   -0.5859  1.0  0.0  0.0
# 3404             :(       neg   -0.4404  1.0  0.0  0.0
# 20737         sorry       neg   -0.0772  1.0  0.0  0.0
# 16404           No.       neg   -0.2960  1.0  0.0  0.0
# 20528        Wrong.       neg   -0.4767  1.0  0.0  0.0

# %%
# Top 10 positive comments
sentiment.sort_values(['pos'], ascending = False)[0:10]
# Out:
#        Unnamed: 0       id           author             responder  \
# 17763       17763  1351540          ADubs62  Executiveabsurdities
# 22932       22932  1380907      Stinkybelly              saddstar
# 23446       23446  1394422          05banks                   3jt
# 3700         3700  1326708     xxbearillaxx                phuicy
# 2524         2524  1324025         corby315      thegreatestprime
# 6958         6958  1332102          rgonzal          soggybooty92
# 5923         5923  1330412   barassmonkey17    crazy_weird_rabbit
# 21247       21247  1363544    StandardFiend            fusterclux
# 843           843  1321845        bazzil350               bigblah
# 11559       11559  1339834  -Mountain-King-             Dsiroon37
#
#                          comment sentiment  compound  neg  neu  pos
# 17763                      Yep.        pos    0.2960  0.0  0.0  1.0
# 22932                    Agreed.       pos    0.2732  0.0  0.0  1.0
# 23446           Congratulations.       pos    0.5994  0.0  0.0  1.0
# 3700                    :)\r\r\n       pos    0.4588  0.0  0.0  1.0
# 2524                      Agree.       pos    0.3612  0.0  0.0  1.0
# 6958   LOL \r\r\n\r\r\nU R FUNNY       pos    0.6908  0.0  0.0  1.0
# 5923                         Lol       pos    0.4215  0.0  0.0  1.0
# 21247                       lmao       pos    0.5994  0.0  0.0  1.0
# 843                      Agreed.       pos    0.2732  0.0  0.0  1.0
# 11559                       yes.       pos    0.4019  0.0  0.0  1.0

# %%
# Plot prevalent sentiment of comments
import seaborn as sns
sns.countplot(x="sentiment", data = sentiment, palette="Greens_d");
plt.ylabel('Number of Comments')
plt.xlabel('Prevalent Sentiment')
plt.show()

# %%
# Plot histograms of all scores
plt.figure(figsize=(18, 18))

plt.subplot(221)
plt.hist(sentiment['neg'], bins='auto')
plt.title("Histogram of Negative Scores")

plt.subplot(222)
plt.hist(sentiment['neu'], bins='auto')
plt.title("Histogram of Neutral Scores")

plt.subplot(223)
plt.hist(sentiment['pos'], bins='auto')
plt.title("Histogram of Positive Scores")

plt.subplot(224)
plt.hist(sentiment['compound'], bins='auto')
plt.title("Histogram of Compound Scores")

plt.show()
plt.gcf().clear()

# %% [markdown]
# ### Merge..

# %%
# Merge sentiment scores and node centralities
avg_sentiment = sentiment.groupby(['responder'])['compound'].agg(['mean', 'count']).reset_index()
avg_sentiment.rename(columns={'responder': 'username', 'mean': 'avg_sentiment'}, inplace=True)
sentiment_analysis = users.merge(avg_sentiment,on=['username'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-94fd9d949b43> in <module>
#       2 avg_sentiment = sentiment.groupby(['responder'])['compound'].agg(['mean', 'count']).reset_index()
#       3 avg_sentiment.rename(columns={'responder': 'username', 'mean': 'avg_sentiment'}, inplace=True)
# ----> 4 sentiment_analysis = users.merge(avg_sentiment,on=['username'])
#
# c:\users\abh9013\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# c:\users\abh9013\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# c:\users\abh9013\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# c:\users\abh9013\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     844                         right_keys.append(rk)
#     845                     if lk is not None:
# --> 846                         left_keys.append(left._get_label_or_level_values(lk))
#     847                         join_names.append(lk)
#     848                     else:
#
# c:\users\abh9013\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'username'

# %% [markdown]
# ### Table showing centrality and sentiments (Table 1:1)

# %%
sentiment_analysis[0:10]

# %%
import numpy as np

x = sentiment_analysis.loc[:,"betweenness"].values
y = sentiment_analysis.loc[:,"avg_sentiment"].values

# Least squares polynomial fit
m, b = np.polyfit(x, y, 1)

plt.figure(figsize=(18, 18))
plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')
plt.xlabel("Betweenness Centrality")
plt.ylabel("Avg. Sentiment")
plt.show()
plt.gcf().clear()

# %%
# Compute Pearson correlation coefficient and the p-value for testing non-correlation
scipy.stats.pearsonr(x, y)

# %%
x = sentiment_analysis.loc[:,"degree"].values
y = sentiment_analysis.loc[:,"avg_sentiment"].values

# Least squares polynomial fit
m, b = np.polyfit(x, y, 1)

plt.figure(figsize=(18, 18))
plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')
plt.xlabel("Degree Centrality")
plt.ylabel("Avg. Sentiment")
plt.show()
plt.gcf().clear()

# %%
# Compute Pearson correlation coefficient and the p-value for testing non-correlation
scipy.stats.pearsonr(x, y)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We found that there is no evidence of centrality and sentiment. We attempted to find out in this project if positive or negative comments increased or decreased the significance of a node in the network. From the Table 1:1 we see the sentiment score and centrality measures are independent of each other.
#
# There were many nodes that were equally important. They formed their own subnetwork. This finding is consistent with the nature of discussion forums. Groups are formed around the topics of discussion.

# %% [markdown]
# In a discussion forum network there could be moderator nodes that is important. These nodes should be eliminated from the network to get a meaningful data. The comments could be emoji, common words and symbols like ditto etc. They are difficult to analyze for sentiments. There is also a complexity of large data. It takes time to load and analyze these datasets. If we need a real-time analysis then we have to stream them and add to the network constantly.

# %% [markdown]
# References:
#
# - https://www.youtube.com/watch?v=HJ4Hcq3YX4k (Gephi)
# - https://www.geeksforgeeks.org/python-sentiment-analysis-using-vader/ (VADER Sentiment Analysis)
