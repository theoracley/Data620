# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# G=nx.Graph()

G = nx.florentine_families_graph()

# %%
nx.draw(G)
# Out:
# c:\users\abh9013\appdata\local\programs\python\python37-32\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
# nx.draw(G, with_labels = True)
# plt.show()


# c = nv.plots.BasePlot(G)
# c.draw_edges()
# c.draw_nodes()
# c.draw()
# plt.show() 

# # visualize graph using pyvis
# g=net.Network(height="800px", width="100%", notebook=True)
# nxg = nx.Graph(G)
# g.from_nx(nxg)
# g.show("basic.html")

# test_G = nx.tutte_graph()
# c = nv.CircosPlot(test_G)
# c.draw()
# plt.show()

# test_G = nx.tutte_graph()
# nx.draw(test_G, with_labels = True)
# plt.show()

# # Assume we have a professional network of physicians belonging to hospitals.
# c = CircosPlot(G, node_color='affiliation', node_grouping='affiliation')
# c.draw()
# plt.show()  # only needed in scripts


#file = 'http://networkdata.ics.uci.edu/data/lesmis/lesmis.gml'
# mydata = requests.get(file)
